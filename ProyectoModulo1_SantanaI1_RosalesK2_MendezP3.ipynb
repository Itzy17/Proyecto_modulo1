# %% [markdown]
# # <font color='darkred'> Proyecto módulo 1
#
# ![image.png](attachment:image.png)
#
# ## <font color='navy'> Entrega final
#
# **Fecha de entrega:** 25 de marzo de 2020.
#
# **Materia:** Simulación de procesos financieros.
#
# **Profesor:** Oscar David Jaramillo Zuluaga.
#
# **Alumnos:**
#
# > Patricia Buenrostro Méndez.
#
# > Kiara Paola Puente Rosales.
#
# > Esther Itzel Sanromán Santana.

# %% [markdown]
# **Enlace github: https://github.com/Itzy17/Proyecto_modulo1**

# %% [markdown]
# ## 1. Accidentes de tránsito.
#
# ### 1.1 Accidentes de tránsito terrestre en zonas urbanas y suburbanas.
# > En este trabajo investigaremos los accidentes de tránsito que se han presentado en 2018, creando simulaciones para observar el número de eventos y así, intentar de disminuir dichos accidentes y concientizar a las personas sobre la gravedad que conlleva el conducir sin estar en nuestros 5 sentidos y prestando atención a todo nuestro alrededor.
# Así como observar la cantidad de mujeres y hombres, comparando el sexo que tiene mayor ocurrencia.
#
#
# ### 1.2 Objetivos.
#
# > #### 1.1 Objetivo general.
# >  - Analizar la cantidad de accidentes automovilísticos que ocurren.
#
# > #### 1.2 Objetivos específicos
# >>  - Evaluar el porcentaje de choques entre hombres y mujeres.
# >>  - Comparar la cantidad de accidentes en mujeres viendo a que edad ocurren más accidentes.
# >>  - Comparar la cantidad de accidentes en hombres viendo a que edad ocurren más accidentes.
# >>  - Calcular la cantidad de decesos y personas con vida entre hombres y mujeres.
#
#
# ### 1.3 Definición del problema.
#
# > Actualmente hay una gran gama de problemas que existen a nivel mundial, continental, nacional, estatal, local, familiar, y personal. Sin embargo la razón por la que decidimos centrarnos en el tema: ACCIDENTES AUTOMOVILÍSTICOS, es debido a que las estadísticas de accidentes automovilísticos son alarmantes. Los Accidentes automovilísticos se deben a la combinación de diversos factores. Y, si se pretende solucionar el problema, es básico que se conozca las causas y consecuencias del problema, y una vez conociendo las características de la problemática podemos proponer más y mejores soluciones.
#
# > Es muy triste que a pesar de los avances de la medicina, y tecnología en los autos, las muertes por accidentes automovilísticos se hayan convertido en uno de los más graves problemas de salud pública.
#
# > Este problema, es un asunto que a todos nos concierne, pues todos hemos experimentado este problema ya sea en nuestra persona, o algún conocido.
#
# > Se han llevado acabo diversas investigaciones sobre accidentes automovilísticos, sin embargo, no hemos logrado solucionar este problema. No podemos permitir que las cifras de accidentes automovilísticos sigan creciendo, es por ello que decidimos hablar sobre este tema, para poder brindar información y por supuesto poder plantear posibles soluciones.
#
# > Como hemos visto en las noticias de los últimos años cada vez se vuelven más recurrentes los accidentes automovilísticos, con el paso del tiempo la gravedad y la incurrencia de este suceso ha ido en aumento. Hemos visto que los motivos por los cuales se presentan los accidentes pueden ser simples descuidos en los cuales muchas veces termina en solo un impacto o por otra parte, acabar en una desgracia.
#
# > En este proyecto se harán simulaciones enfocándonos en las principales preguntas que se vienen a tu mente cuando ocurre un accidente automovilístico, entonces, nuestros 4 nodos serán:
#
# >> a) **Las víctimas que están involucradas**, es decir, número de personas fallecidas y/o heridas que iban en los respectivos autos.
#
# >> b) **Los autos que están involucrados**, será el número de autos que estuvieron en el percance, especificando que tipo de vehículo estuvo involucrado, por ejemplo: microbús, bicicleta, camión de carga, entre otros.
#
# >> c) **Sexo**, en este apartado especificaremos la cantidad de hombres y/o de mujeres que se presentaron en el desastre. En caso de que alguna persona se haya fugado existe un apartado en el cual se mostrará la cantidad de vehículos que se dieron a la fuga.
#
# >> d) **Edad**, en este último nodo se darán a conocer si los participantes eran menores o mayores de edad.
#
# > El objetivo principal de este proyecto es ofrecer al lector información sobre los accidentes automovilísticos con altos índices de muertes y lo que es más alarmante, que los adolescentes y adultos jovenes son los más involucrados en ellos.
#
# > Así como también por medio de este trabajo se planea conocer todas las causas de los accidentes y de alguna forma tratar de evitarlos. A través de esta investigación se pretende evitar a toda costa que estos terribles accidentes sigan sucediendo, realizando campañas que estén dirigidas a los jóvenes de preparatoria y a los jóvenes universitarios, para sí poder reducir el índice de los accidentes producidos por éstos.
#
# > En conclusión, muchos de los accidentes que ocurren los podríamos evitar sencillamente prestando un poco más de atención a nuestro alrededor, porque muchas veces no es que tu conduzcas mal o no pongas suficiente atención, más bien es que la otra persona no estaba 100% concentrada sobre los movimientos que se hacen al conducir.
#
#
#
# ### 1.4 Nodos y variables que se decidieron simular y porqué
# > Las variables que vamos a abordar en este proyecto son:
#
# - Edad
# - Sexo
# - Las víctimas que están involucradas.
# - Los autos que están involucrados.
#
# Decidimos simular estos nodos porque cuando ocurre algún accidente automovilístico, lo primero que se preguntan las personas tanto civiles como autoridades, es el número de personas, sexo y edad.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 1.5 Hipótesis y supuestos
# > Para este proyecto se harán simulaciones sobre los choques de autos, en las cuales tomaremos ciertos supuesto y realizaremos hipótesis viendo si suceden o no.
#
# > **Supuestos**
# - Se dice que no hay menores de edad manejando.
# - Los eventos son independientes.
# - Se usarán datos del 2018, todos los accidentes registrados en ese periodo.
#
# > **Hipótesis**
# - $H_1$ La edad de más recurrencia en conductores accidentados es de 22 años.
# - $H_2$ El sexo más involucrado en los accidentes es masculino.
# - $H_3$ El sexo más involucrado en defunciones es femenino.
# - $H_4$ El vehículo más accidentado es el automóvil.
# - $H_5$ La edad de más recurrencia en conductores que mueren es de 30 años.

# %% [markdown]
# ### 1.6 Obtención de bases de datos
#
# Para este proyecto nuestra base de datos la sacamos de una página de road safety en donde venían 3 bases de datos. La primera vehiculos, la segunda damnificados y accidentes, todas estas en 2018.
#
# Estas bases de datos eran extremadamente largas así que decidimos acortarlas, esto porque se tomaba el total de accidentes registrados, no solo por día sino por minuto.
#
# https://data.gov.uk/dataset/cb7ae6f0-4be6-4935-9277-47e5ce24a11f/road-safety-data

# %%
# Importamos librerías
import pandas as pd
import numpy as np 
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.special as sps 
import statsmodels.api as sm
import sklearn; #print( "  scikit-learn:", sklearn.__version__)
import scipy; #print ("  scipy:", scipy.__version__)
import statsmodels; #print( "  statsmodels:", statsmodels.__version__)
from scipy import optimize
from scipy.stats import beta
from math import factorial as fac
from scipy.stats import erlang
from sklearn.preprocessing import PolynomialFeatures
from sklearn import linear_model
from scipy.stats.distributions import norm
from sklearn.neighbors import KernelDensity
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KernelDensity
from scipy.stats import gaussian_kde
from statsmodels.nonparametric.kde import KDEUnivariate
from statsmodels.nonparametric.kernel_density import KDEMultivariate

# %%
# Funciones que podemos utilizar
# Creamos la función que crea muestras distribuidas exponencialmente
def D_exponential(theta,N):
    return -np.log(np.random.random(N))*theta

def Multi_Graph_plot(datos, etiquetas, titulo, y_label):
    [plt.plot(datos.iloc[:,i], label = etiquetas[i]) for i in range(len(datos.iloc[0]))]
    plt.title(titulo)   # Establece el título del gráfico
    plt.xlabel("Time")   # Establece el título del eje x: abscisa
    plt.xticks(rotation=90)
    plt.ylabel(y_label)   # Establece el título del eje y: ordenada
    plt.legend(loc='upper left') 
    
#Funcion histograma
def Graph_hist(datos, titulo, y_label):
    [freq,x,p] = plt.hist(datos, density = True, alpha = 0.3, bins = 40)
    plt.title(titulo)   # Establece el título del gráfico
    plt.xlabel("Time")   # Establece el título del eje x: abscisa
    plt.ylabel(y_label)   # Establece el título del eje y: ordenada
    plt.show()
    return freq, x, p

def plot_histogram_discrete(distribucion:'distribución a graficar histograma',
                            label:'label del legend'):
    # len(set(distribucion)) cuenta la cantidad de elementos distintos de la variable 'distribucion'
    plt.figure(figsize=[8,4])
    y,x = np.histogram(distribucion,bins = len(set(distribucion))) 
    plt.bar(list(set(distribucion)),y,label=label)
    plt.legend()
    plt.show()

def Hist_emp_Best_dist_line(Y, best_dist, title):
    dist = getattr(st, best_dist)
    x = np.linspace(min(Y),max(Y), len(Y))
    param = dist.fit(Y)
    pdf_fitted = dist.pdf(x, *param[:-2], loc=param[-2], scale=param[-1])
    
    #Graficas
    plt.plot(x,pdf_fitted)
    plt.hist(Y, alpha = 0.5, density = True, bins=15)
    plt.title(title) 
    
def Gen_distr_discreta(U:'vector de números aleatorios',
                       p_acum: 'P.Acumulada de la distribución a generar'):
    '''Tener en cuenta que este arreglo cuenta números empezando del 0'''
    v = np.array(list(map(lambda j:sum(1 for i in p_acum if i<U[j]),range(N))))
    return v
    
# Función que calcula la probabilidad acumulada optimizada    
def P_acum_Binomial_o(n,p):
    Pr = np.zeros(n)
    Pr[0] = (1-p)**n
    def pr(i):
        nonlocal Pr
        c  = p/(1-p)
        Pr[i+1]=(c*(n-i)/(i+1))*Pr[i]
        
    # Lleno el vector Pr usando compresión de listas
    [pr(i) for i in range(n-1)]
    return np.cumsum(Pr)

# Función para crear variables aleatorias Erlang
def D_erlang(theta:'media distrubucion',k,N):
    f = np.random.rand(N,k)  # Matriz de variables aleatorias de dim N*k mejora la velocidad del algoritmo
    y =list(map(lambda i:-(theta) * np.log(np.prod(f[i,:])),range(N)))
    return y

def plot_hist(theta, k, N):
    r1 = D_erlang(theta, k, N)
    y, x, _ = plt.hist(r1, bins=50, density=True)
    x = np.arange(0, 30, 0.01)
    y2 = x**(k-1)*(np.exp(-x/theta) /(sps.gamma(k)*theta**k))
    plt.plot(x,y2,'r--')
    plt.show()
    
def best_fit_distribution(data, bins=200, ax=None):
    """Model data by finding best fit distribution to data"""

    y, x = np.histogram(data, bins=bins, density=True)
    x = (x + np.roll(x, -1))[:-1] / 2.0


    DISTRIBUTIONS = [
    st.alpha,st.anglit,st.arcsine,st.beta,st.betaprime,st.bradford,st.burr,st.cauchy,st.chi,st.chi2,st.cosine,
    st.dgamma,st.dweibull,st.erlang,st.expon,st.exponnorm,st.exponweib,st.exponpow,st.f,st.fatiguelife,st.fisk,
    st.foldcauchy,st.foldnorm,st.frechet_r,st.frechet_l,st.genlogistic,st.genpareto,st.gennorm,st.genexpon,
    st.genextreme,st.gausshyper,st.gamma,st.gengamma,st.genhalflogistic,st.gilbrat,st.gompertz,st.gumbel_r,
    st.gumbel_l,st.halfcauchy,st.halflogistic,st.halfnorm,st.halfgennorm,st.hypsecant,st.invgamma,st.invgauss,
    st.invweibull,st.johnsonsb,st.johnsonsu,st.ksone,st.kstwobign,st.laplace,st.levy,st.levy_l,st.levy_stable,
    st.logistic,st.loggamma,st.loglaplace,st.lognorm,st.lomax,st.maxwell,st.mielke,st.nakagami,st.ncx2,st.ncf,
    st.nct,st.norm,st.pareto,st.pearson3,st.powerlaw,st.powerlognorm,st.powernorm,st.rdist,st.reciprocal,
    st.rayleigh,st.rice,st.recipinvgauss,st.semicircular,st.t,st.triang,st.truncexpon,st.truncnorm,st.tukeylambda,
    st.uniform,st.vonmises,st.vonmises_line,st.wald,st.weibull_min,st.weibull_max,st.wrapcauchy
    ]


    best_distribution = st.norm
    best_params = (0.0, 1.0)
    best_sse = np.inf

    #Estimamos parametros
    for distribution in DISTRIBUTIONS:

    # aplicamos la funcion fit a los datos
        try:

            with warnings.catch_warnings():
                warnings.filterwarnings('ignore')

                params = distribution.fit(data)

                arg = params[:-2]
                loc = params[-2]
                scale = params[-1]

                pdf = distribution.pdf(x, loc=loc, scale=scale, *arg)
                sse = np.sum(np.power(y - pdf, 2.0))


                # Verificamos si le queda mejor la distribucion a los datos
                if best_sse > sse > 0:
                    best_distribution = distribution
                    best_params = params
                    best_sse = sse

        except Exception:
            pass

    return (best_distribution.name, best_params)

def obtener_var_aleatorias(datos, N=200):
    t = lambda x: max(datos.pdf) * np.ones(len(x))
    x = np.arange(0, datos.max(), 1)
    
    plt.plot(x, datos.funcion(x), label = "f[x]")
    plt.plot(x, t(x), label="t[x]")
    plt.legend()
    
    R2 = np.random.rand(N)
    R1 = np.random.uniform(0, datos.max(), N)
    random_variables = Acep_rechazo(R2,R1,datos.funcion, t)
    return random_variables
                                                
def obtencionVariablesAleatorias(Instancias, N=10000):
    t = lambda x: max(Instancias.pdf) * np.ones(len(x))
    x = np.arange(0, Instancias.max_data, 1)
    
    R2 = np.random.rand(N)
    R1 = np.random.uniform(0, Instancias.max_data, N)
    random_variables = Acep_rechazo2(R2,R1,Instancia.f, t)
    return print(random_variables.mean())
                                                
# Función de aceptación y rechazo usando compresión de listas
def Acep_rechazo(R2:'Variables distruidas U~U(0,1)',
                 R1:'Variables distribuidas como g(x)',
                 f:'función objetivo a generar',
                 t:'función que mayora a f'):
#     R1 = np.random.rand(N)
    f_x = f(R1)
    t_x = t(R1)
    condition = R2*t_x <=f_x
    [plt.plot(R1[i],R2[i]*t_x[i],'ob') if condition[i] else plt.plot(R1[i],R2[i]*t_x[i],'o') \
         for i in range(len(R1))]
    return [R1[i] for i in range(len(R1)) if condition[i]]

# Función de aceptación y rechazo usando compresión de listas
def Acep_rechazo2(R2:'Variables distruidas U~U(0,1)',
                 R1:'Variables distribuidas como g(x)',
                 f:'función objetivo a generar',
                 t:'función que mayora a f'):
#     R1 = np.random.rand(N)
    f_x = f(R1)
    t_x = t(R1)
    condition = R2*t_x <=f_x
    j = 0
    i = 0
    k = np.zeros(N)
    while j < N:
        if condition[i]:
            k[j] = R1[i]
            j = j + 1
            i = i + 1
        else:
            i = i + 1
    return k

def acep_rechazo(R2:'Variables distruidas U~U(0,1)',
                 R1:'Variables distribuidas como g(x)',
                 f:'función objetivo a generar',
                 t:'función que mayora a f'):
    f_x = f(R1)
    t_x = t(R1)
    condition = R1*t_x <= f_x
    variables_aleatorias = []
    i = 0
    while len(variables_aleatorias) < N:
        if condition[i]:
            variables_aleatorias.append(R1[i])
            i+=1
            return np.array(variables_aleatorias)
    
#creando la función
global pdf
def kernel(lista: "Insertar la lista con los datos", 
                   titulo: "Insertar lista de títulos"):
    grid = GridSearchCV(KernelDensity(), #Busca el ancho óptimo.
                       {"bandwidth": np.linspace(0.1,lista.max(),1000)},
                       cv=20) #20-fold cross-validation
    grid.fit(lista[:,None])
    kde = grid.best_estimator_
    pdf = np.exp(kde.score_samples(np.linspace(0.1,lista.max(),1000)[:, None])) #Kernel
    
    plt.figure()
    plt.plot(np.linspace(0.1,lista.max(),1000), pdf, linewidth=3, alpha=0.5, label = "bw=%.2f" % kde.bandwidth)
    plt.hist(lista,10,fc="gray",histtype="stepfilled",alpha=0.3, density=True)
    plt.legend(loc="upper left")
    plt.title(titulo)
    plt.show()
    return pdf, grid

def calc_KDE(data, title):
    #Calculat KDE
    kde = sm.nonparametric.KDEUnivariate(data)
    kde.fit(kernel='gau', bw='silverman')
    #Graph
    plt.plot(kde.support, kde.density, lw=3, label='KDE from samples', zorder=10)
    plt.hist(data, density = True, alpha = 0.4, bins = 5)
    plt.title(title)
    return kde

def kde_sklearn(x, x_grid, bandwidth=0.2, **kwargs):
    """Kernel Density Estimation with Scikit-learn"""
    kde_skl = KernelDensity(bandwidth=bandwidth, **kwargs)
    kde_skl.fit(x[:, np.newaxis])
    # score_samples() returns the log-likelihood of the samples
    log_pdf = kde_skl.score_samples(x_grid[:, np.newaxis])
    return np.exp(log_pdf)

def kde_sklearn1(x, x_grid, bandwidth=0.2, **kwargs):
    """Kernel Density Estimation with Scikit-learn"""
    kde_skl = KernelDensity(bandwidth=bandwidth, **kwargs)
    kde_skl.fit(x[:, np.newaxis])
    # score_samples() returns the log-likelihood of the samples
    pdf = lambda x: np.exp(kde_skl.score_samples(x[:, np.newaxis]))
    return pdf

def kde_scipy(x, x_grid, bandwidth=0.2, **kwargs):
    """Kernel Density Estimation with Scipy"""
    # Note that scipy weights its bandwidth by the covariance of the
    # input data.  To make the results comparable to the other methods,
    # we divide the bandwidth by the sample standard deviation here.
    kde = gaussian_kde(x, bw_method=bandwidth / x.std(ddof=1), **kwargs)
    return kde.evaluate(x_grid)


def kde_statsmodels_u(x, x_grid, bandwidth=0.2, **kwargs):
    """Univariate Kernel Density Estimation with Statsmodels"""
    kde = KDEUnivariate(x)
    kde.fit(bw=bandwidth, **kwargs)
    return kde.evaluate(x_grid)
    
    
def kde_statsmodels_m(x, x_grid, bandwidth=0.2, **kwargs):
    """Multivariate Kernel Density Estimation with Statsmodels"""
    kde = KDEMultivariate(x, bw = 'cv_ml',#bw=bandwidth * np.ones_like(x),
                          var_type='c', **kwargs)
    return kde.pdf(x_grid)

kde_funcs = [kde_statsmodels_u, kde_statsmodels_m, kde_scipy, kde_sklearn]
kde_funcnames = ['Statsmodels-U', 'Statsmodels-M', 'Scipy', 'Scikit-learn']

# %%
datos = pd.read_csv('base.csv', index_col = "Date")
datos = datos.iloc[:, 1:10]
datos.head()
# Out:
#           Accident_Severity  Number_of_Vehicles  Number_of_Casualties  \
# Date
# 01/01/18                  3                   1                     2
# 01/01/18                  3                   1                     1
# 01/01/18                  3                   1                     1
# 01/01/18                  2                   1                     1
# 01/01/18                  2                   2                     2
#
#           Day_of_Week  Time  Sex_of_Driver  Sex_of_Casualty  Age_of_Driver  \
# Date
# 01/01/18            2  1:30              1                2             57
# 01/01/18            2  0:50              1                1             48
# 01/01/18            2  0:45              1                1             22
# 01/01/18            2  3:00              1                1             40
# 01/01/18            2  2:20              1                1             28
#
#           Age_of_Casualty
# Date
# 01/01/18               50
# ...

# %%
datos.describe()
# Out:
#        Accident_Severity  Number_of_Vehicles  Number_of_Casualties  \
# count         263.000000          263.000000            263.000000
# mean            2.825095            2.490494              1.231939
# std             0.427822            1.893869              0.679166
# min             1.000000            1.000000              1.000000
# 25%             3.000000            1.000000              1.000000
# 50%             3.000000            2.000000              1.000000
# 75%             3.000000            3.000000              1.000000
# max             4.000000           10.000000              7.000000
#
#        Day_of_Week  Sex_of_Driver  Sex_of_Casualty  Age_of_Driver  \
# count   263.000000     263.000000       263.000000     263.000000
# mean      4.555133       1.288973         1.342205      43.239544
# std       1.724266       0.454150         0.475353      13.443110
# min       1.000000       1.000000         1.000000      19.000000
# ...

# %% [markdown]
# En esta tabla podemos ver el general de nuestros datos, nos dice cuantos datos hay de cada columna, su media y desviación estándar, mínimo, máximo, los cuartiles, etc.

# %% [markdown]
# ## <font color = "darkgreen"> Nodo 1: Edad

# %% [markdown]
# En este primer nodo se hará el análisis de los conductores y personas en el automóvil, veremos a que edad hay más personas conduciendo.

# %%
edad = datos.iloc[:, 7:8]

# %%
para1 = st.norm.fit(datos['Age_of_Driver'])

# %%
hist_edad = edad.plot.hist(grid=True, bins=20, rwidth=0.9, color='navy')

# %% [markdown]
# En el histograma podemos observar que la edad más frecuente de los conductores es de 35 años aprox.
#
# A simple vista se puede observar que la distribución es normal, pero para esto hacemos una prueba de quartil - quartil.

# %%
best_fit_distribution(edad)
# Out:
# ('norm', (0.0, 1.0))

# %% [markdown]
# ### **Prueba quantil-quantil**

# %%
# Histograma de las variables creadas
divisiones = 100 # Cantidad de barras en el histograma
plt.hist(datos['Age_of_Driver'], divisiones, density=True,label='Edad del conductor')
x = np.arange(18,90,.01)
y = st.norm.pdf(x, loc=para1[0], scale=para1[1])
plt.plot(x, y, 'k--')
plt.ylabel('Probability')
plt.grid()
plt.show()

# Gráfica de Q-Q entre las muestras creadas y una curva normal
st.probplot(datos['Age_of_Driver'], (para1[0],para1[1]), dist="norm", plot=plt)
plt.grid()
plt.title('Distribución normal')
plt.xlabel('Normal theorical quantiles')
plt.ylabel('Data theorical quantiles')
plt.show()

# %% [markdown]
# Podemos observar que es una distribución normal ya que los puntos se ajustan lo más posible a la línea recta.

# %%
f, axes = plt.subplots(figsize=(10, 6), sharex=True)
# Plot a simple histogram with binsize determined automatically
a = sns.distplot(edad, color="darkblue", fit=st.norm, norm_hist=True)

# %% [markdown]
# Este es un ajuste comparando nuestra gráfica con una distribución normal.
#
# La línea azul que podemos observar en el histograma es la que más se ajusta.

# %%
mu = np.mean(edad)
sigma = np.std(edad)
print("La media es  = ", mu)
print("La desviación estándar es = ", sigma)
# Out:
# La media es  =  Age_of_Driver    43.239544
# dtype: float64
# La desviación estándar es =  Age_of_Driver    13.417529
# dtype: float64

# %% [markdown]
# ### Se desea resolver la siguiente prueba de hipótesis
# > $H_0$: la distribución es normal con ´media= $\mu$´ y ´desviación estándar = $\sigma$´
#
# > $H_a$: los datos no se distribuyen normales

# %%
np.random.seed(555)
mu_real = mu; sigma_real = sigma
N = 100 # Cantidad de muestras
n1 = datos["Age_of_Driver"]
# datos aqui en n1 para el proyecto
J = 90  # Cantidad de particiones del histograma
[freq,x,p] = plt.hist(n1,J,density=True)
plt.show()
# Se obvia el último valor de x para obtener exactamente J muestras de x
x = x[:-1] 
# Media y desviación estándar muestral
mu = np.mean(x)
sigma = np.std(x)
print('media mu =%f, desviación estándar muestral =%f'%(mu, sigma))
st.norm.fit(x)
# Out:
# media mu =48.666667, desviación estándar muestral =17.319439
# (48.666666666666664, 17.319438875522582)

# %% [markdown]
# Sabemos que al obtener misma mu y misma desviación los calculos fueron correctamente realizados.

# %%
pi = st.norm.pdf(x,loc=mu,scale=sigma)
# Cálculo de la esperanza usando la expresión teórica
Ei = x*pi
# Cálculo teórico de la chi cuadrada
x2 = np.sum(list(map(lambda Ei,obs_i:(obs_i-Ei)**2/Ei,Ei,freq)))
print('Valor de chi cuadrado teorico  = ',x2)

# Cálculo usando la librería estadística de la chi cuadrada
X2 = st.chisquare(freq,Ei)
print('Valor de chi cuadrado librería = ',X2)

# Cálculo de Grados de libertad del estadístico
p = 2 # Parámetros estimados con los datos
m = J-p-1 # grados de libertad

Chi_est = st.chi2.ppf(q = 0.95, df=m)
print('Estadístico de chi_cuadrado = ', Chi_est)
print('Media muestral = ', mu, '\nDesviación estándar muestral = ', sigma)
# Out:
# Valor de chi cuadrado teorico  =  64.02478722914138
# Valor de chi cuadrado librería =  Power_divergenceResult(statistic=64.02478722914138, pvalue=0.978902766607369)
# Estadístico de chi_cuadrado =  109.77330935028795
# Media muestral =  48.666666666666664
# Desviación estándar muestral =  17.319438875522582

# %% [markdown]
# Al ver que el chi cuadrado teoríco es igual al de la librería y que la media y desviación son iguales a lo anteriormente dado, vemos que ciertamente es una distribución normal.
#
# Al obtener un pvalue de 0.978902 decimos que $H_0$ acepta, es decir, los datos se distribuyen normalmente.

# %% [markdown]
# ### Hacemos la conversión a kernel para poder hacer que se ajuste muy bien y después de esto obtenemos la función para poder hacer aceptación y rechazo.

# %%
[kernel(datos["Age_of_Driver"], "Edad")]
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# [(array([0.00000000e+000, 0.00000000e+000, 0.00000000e+000, 0.00000000e+000,
#          0.00000000e+000, 0.00000000e+000, 0.00000000e+000, 0.00000000e+000,
#          0.00000000e+000, 0.00000000e+000, 0.00000000e+000, 0.00000000e+000,
#          0.00000000e+000, 0.00000000e+000, 0.00000000e+000, 0.00000000e+000,
#          0.00000000e+000, 0.00000000e+000, 0.00000000e+000, 0.00000000e+000,
#          0.00000000e+000, 0.00000000e+000, 0.00000000e+000, 0.00000000e+000,
#          0.00000000e+000, 0.00000000e+000, 0.00000000e+000, 0.00000000e+000,
#          0.00000000e+000, 0.00000000e+000, 0.00000000e+000, 0.00000000e+000,
# ...

# %%
x1 = datos["Age_of_Driver"]
grid = GridSearchCV(KernelDensity(),
                    {'bandwidth': np.linspace(0.1, 1.0, 30)},
                    cv=20) # 20-fold cross-validation
grid.fit(x1[:, None])
print(grid.best_params_)
x_grid = np.linspace(0.1, x1.max(), 1000)
kde = grid.best_estimator_
pdf = np.exp(kde.score_samples(x_grid[:,None]))

fig, ax = plt.subplots(figsize=(15,7))
ax.plot(x_grid, pdf, linewidth=3, alpha=0.5, label='bw=%.2f' % kde.bandwidth)
ax.hist(x1, 100, fc='gray', histtype='stepfilled', alpha=0.3, density=True)
ax.legend(loc='upper left')
ax.set_xlim(18, 90)
# Out:
# {'bandwidth': 0.16206896551724137}
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# (18, 90)

# %% [markdown]
# La gráfica anterior nos muestra, en color gris las edades existentes entre los conductores, mientras que las curvas azules muestran el kernel del tipo de datos que tenemos.

# %%
x_grid = np.linspace(x1.min(),x1.max(),x1.max())
x1_grid = np.linspace(0.1, x1.max(), 1000)
funcion = kde_sklearn1(x1,x1_grid)
funcion
# Out:
# <function __main__.kde_sklearn1.<locals>.<lambda>(x)>

# %%
x = np.arange(0, x1.max() + 1)
f = funcion
max_f = max(funcion(x))
t = lambda x: max_f * np.ones(len(x)) 

print('El maximo de f es:', max_f)

#Graficas de las funciones
plt.subplots(figsize=(8,6))
plt.title("Edades", size= 20)
plt.xlabel("Edades")
plt.ylabel("Probabilidad")
plt.plot(f(x), label='f(x)', linewidth=2, color = 'purple')
#plt.plot(t(x), label= 't(x)', linewidth=2, color = 'orange')

N = 500
R2 = np.random.uniform(0,1,N)
R1 = np.round(np.random.uniform(0, 80, N), 0)

aceptar1 = Acep_rechazo(R2, R1, f, t)
# Out:
# El maximo de f es: 0.0910138719697702

# %%
# Método montecarlo estándar 
monte_estandar = aceptar1
plt.hist(monte_estandar,30,density=True, color="lightblue")
plt.title('Montecarlo estándar')
plt.show()

# %% [markdown]
# ### Por último, hacemos simulaciones con la distribución que tenemos de los datos

# %%
n = [10, 1000, 10000, 100000, 1000000]
simu_edades =   list(map(lambda n: np.random.normal(np.mean(datos["Age_of_Driver"]), np.std(datos["Age_of_Driver"]), n), n))
prob = list(map(lambda x: np.mean(x), simu_edades)) 
d = pd.DataFrame(data={'Simulaciones':prob},index=n)
d
# Out:
#          Simulaciones
# 10          46.364855
# 1000        43.268047
# 10000       43.415226
# 100000      43.238150
# 1000000     43.228630

# %% [markdown]
# Aquí vemos las simulaciones utilizando numpy y la media y desviación de los datos, esto para poder decir que tras varias simulaciones el rango de edad estará más o menos entre los 42 y 45 años.

# %%
n = [10, 1000, 10000, 100000, 1000000]
simu_edad = list(map(lambda n:st.norm.rvs(loc=para1[0], scale=para1[1], size=n), n))
prob = list(map(lambda x: np.mean(x), simu_edad)) 
x = pd.DataFrame(data={'Simulaciones':prob}, index=n)
x
# Out:
#          Simulaciones
# 10          43.609395
# 1000        43.665374
# 10000       43.230292
# 100000      43.232122
# 1000000     43.246088

# %% [markdown]
# Aquí por el contrario, utilizamos método de montecarlo para hacer la simulación, creando número aleatorios que se distribuyan de manera normal, tal como es nuestra distribución.
#
# Se puede observar que el rango de edad entre los 43 y los 45 años de edad.

# %%
N = 1000
# Método montecarlo estándar 
monte_estandar = st.norm.ppf(np.random.rand(N), loc=para1[0], scale=para1[1])
plt.hist(monte_estandar,30,density=True, color="lightblue")
plt.title('Montecarlo estándar')
plt.show()
monte_estandar.mean()
# Out:
# 42.23294149265161

# %% [markdown]
# Para concluir con el primero nodo hicimos un histograma con números aleatorios entre nuestros parámetros y la distribución que tenemos.

# %% [markdown]
# Con las simulaciones y el histograma anterior podemos rechazar la hipótesis.

# %% [markdown]
# ## <font color = "darkgreen"> Nodo 2: Sexo

# %% [markdown]
# En este nodo se analizarán los datos sobre el sexo, dividiéndose en 2. Es decir:
#
# - 1 para los hombres
#
# - 2 para las mujeres
#
# Así podremos analizar si los hombres o las mujeres son los o las que más recurrentemente tienen más accidentes automovilísticos.

# %%
sexo = datos.iloc[:, 5:6]

# %%
hist_sexo = sexo.plot.hist(grid=True, bins=2, rwidth=0.9, color='orange')

# %% [markdown]
# Con el histograma observamos que, como lo mencionamos en nuestras hipótesis, el sexo más involucrado en los conductores es el masculino, cumpliéndose así, un punto de las mismas.

# %%
best_fit_distribution(sexo)
# Out:
# ('norm', (0.0, 1.0))

# %%
para2 = st.gamma.fit(datos['Sex_of_Driver'])

# %% [markdown]
# ### **Prueba quantil-quantil**

# %%
# Histograma de las variables creadas
divisiones = 50  # Cantidad de barras en el histograma
plt.hist(datos['Sex_of_Driver'], divisiones, density=True,label='Sexo del conductor')
x = np.arange(0,10,.1)
y = st.gamma.pdf(x, para2[0], loc=para2[1], scale=para2[2])
plt.plot(x, y, 'k--')
plt.ylabel('Probability')
plt.grid()
plt.show()

# Gráfica de Q-Q entre las muestras creadas 
grap1 = st.probplot(datos['Number_of_Vehicles'], (para2[0],para2[1]), dist="gamma", plot=plt)
plt.grid()
plt.show()

# %%
f, axes = plt.subplots(figsize=(10, 6))
# Plot a simple histogram with binsize determined automatically
sns.distplot(sexo, color="orange", fit=st.expon)

# %% [markdown]
# La línea naranja que podemos observar en el histograma, es la que mejor se ajusta, y efectivamente, su mayor "pico" está en el número 1, es decir, hombres.

# %%
kernel(datos['Sex_of_Driver'], "Sexo")
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# (array([7.30919262e-18, 8.67220538e-18, 1.02856705e-17, 1.21949091e-17,
#         1.44533138e-17, 1.71237628e-17, 2.02802768e-17, 2.40099614e-17,
#         2.84152806e-17, 3.36167204e-17, 3.97559047e-17, 4.69992411e-17,
#         5.55421843e-17, 6.56142201e-17, 7.74846888e-17, 9.14695874e-17,
#         1.07939513e-16, 1.27328931e-16, 1.50146992e-16, 1.76990145e-16,
#         2.08556841e-16, 2.45664669e-16, 2.89270315e-16, 3.40492807e-16,
#         4.00640565e-16, 4.71242882e-16, 5.54086530e-16, 6.51258325e-16,
#         7.65194586e-16, 8.98738601e-16, 1.05520735e-15, 1.23846896e-15,
#         1.45303257e-15, 1.70415258e-15, 1.99794952e-15, 2.34155009e-15,
# ...

# %%
x2 = datos['Sex_of_Driver']
grid = GridSearchCV(KernelDensity(),
                    {'bandwidth': np.linspace(0.1, 1.0, 30)},
                    cv=20) # 20-fold cross-validation
grid.fit(x1[:, None])
print(grid.best_params_)
x2_grid = np.linspace(0.1, x2.max(), 1000)
# Out:
# {'bandwidth': 0.16206896551724137}
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)

# %%
x2_grid = np.linspace(0.1, x2.max(), 1000)
funcion2 = kde_sklearn1(x2, x2_grid)
funcion2
# Out:
# <function __main__.kde_sklearn1.<locals>.<lambda>(x)>

# %%
x = np.arange(0, x2.max() + 1)
f = funcion2
max_f = max(funcion2(x))
t = lambda x: max_f * np.ones(len(x)) 

print('El maximo de f es:', max_f)

#Graficas de las funciones
plt.subplots(figsize=(8,6))
plt.title("Sexo", size= 20)
plt.xlabel("Sexo")
plt.ylabel("Probabilidad")
plt.plot(f(x), label='f(x)', linewidth=2, color = 'purple')
#plt.plot(t(x), label= 't(x)', linewidth=2, color = 'orange')

N = 500
R2 = np.random.uniform(0,1,N)
R1 = np.round(np.random.uniform(0, 10, N), 0)

aceptar2 = Acep_rechazo(R2, R1, f, t)
# Out:
# El maximo de f es: 1.4182950461169395

# %%
# Método montecarlo estándar 
monte_estandar = aceptar2
plt.hist(monte_estandar,2, rwidth=0.9,density=True, color="lightblue")
plt.title('Montecarlo estándar')
plt.show()

# %%
prob1 = (datos['Sex_of_Driver']==1)/263
prob2 = (datos['Sex_of_Driver']==1)/526
prob = [prob1 + prob2]
p_acum = np.cumsum(prob)
p_acum
# Out:
# array([0.00570342, 0.01140684, 0.01711027, 0.02281369, 0.02851711,
#        0.03422053, 0.03992395, 0.04562738, 0.0513308 , 0.0513308 ,
#        0.0513308 , 0.05703422, 0.06273764, 0.06273764, 0.06273764,
#        0.06844106, 0.07414449, 0.07984791, 0.08555133, 0.09125475,
#        0.09695817, 0.09695817, 0.1026616 , 0.10836502, 0.11406844,
#        0.11977186, 0.12547529, 0.13117871, 0.13117871, 0.13117871,
#        0.13688213, 0.13688213, 0.14258555, 0.14828897, 0.14828897,
#        0.1539924 , 0.15969582, 0.16539924, 0.16539924, 0.17110266,
#        0.17680608, 0.18250951, 0.18821293, 0.18821293, 0.19391635,
#        0.19961977, 0.20532319, 0.21102662, 0.21673004, 0.22243346,
#        0.22813688, 0.2338403 , 0.23954373, 0.24524715, 0.25095057,
#        0.25665399, 0.26235741, 0.26806084, 0.27376426, 0.27376426,
#        0.27946768, 0.2851711 , 0.29087452, 0.29657795, 0.30228137,
#        0.30798479, 0.31368821, 0.31939163, 0.32509506, 0.33079848,
# ...

# %%
hombres = (datos['Sex_of_Driver'] == 1).sum()
mujeres = (datos['Sex_of_Driver'] == 2).sum()
total = hombres + mujeres
hombres, mujeres, total
# Out:
# (187, 76, 263)

# %% [markdown]
# Tenemos un total de 263 personas registradas, de las cuales 187 son hombres y 76 son mujeres.

# %%
prob_hom = hombres/total
prob_muj = mujeres/total
prob_hom, prob_muj
# Out:
# (0.7110266159695817, 0.2889733840304182)

# %% [markdown]
# La probabilidad de que el conductor sea hombre es del 71.10%, mientras que la probabilidad de que sea mujer es de 28.89%.

# %%
prob_hom = [0.7110266159695817]
prob_muj = [0.2889733840304182]

data = pd.DataFrame(columns = ["Probabilidad_hombre", "Probabilidad_mujer", "P_acumulada"])
data.index.name = "Numero_ventas"
data["Probabilidad_hombre"] = prob_hom
data["Probabilidad_mujer"] = prob_muj
data["P_acumulada"] = data["Probabilidad_hombre"] + data["Probabilidad_mujer"]
data
# Out:
#    Probabilidad_hombre  Probabilidad_mujer  P_acumulada
# 0             0.711027            0.288973          1.0

# %%
u = np.random.rand(N)
Gen_distr_discreta(u, p_acum)
# Out:
# array([167, 167,  97,  18,  67, 225,  32,  32, 127,  48, 183, 155,  85,
#          1,  97,  23,  67, 226, 180, 191,  33, 237, 127, 127,  70,  39,
#        121,  17, 199, 202,  94,  61, 148, 185, 172, 109, 126,  17, 181,
#         64, 149, 134, 208,  16,  22,  82, 177,   2,  26,  81,  68,  64,
#        145, 220, 165,   0,  16, 167, 150, 172, 158,  16, 190,  12, 131,
#        207,  23, 235,  42, 208,  18,   7,  55, 244, 241, 235,  46,  44,
#         49,  55,  23,  67,  24, 155,  24,  37, 195, 135, 114, 208,  97,
#         96, 119,  40,  32, 205, 143, 115, 238, 148,  36,   8, 184,  60,
#          7, 119,  67,  69,  37, 140, 204,  33, 155,  86,  26, 205,  49,
#        129,   2, 108, 226,  94,  45, 135, 178,  49, 129, 149, 245, 148,
#        244,  26,  94,  57, 135,  67,  25,  11, 220,  58, 123, 185,  69,
#         73, 144, 235, 206, 241,  69, 204, 133, 170,  54,  62, 152, 217,
#        186, 175,  26,  52, 172,  39, 187, 225, 205,  20,  23,  87,   4,
# ...

# %%
n = [10, 1000, 10000, 100000, 1000000]
simu_sexo = list(map(lambda n: st.gamma.rvs(para2[0], loc=para2[1], scale=para2[2], size=n), n))
prob = list(map(lambda x: np.mean(x), simu_sexo)) 
x = pd.DataFrame(data={'Simulaciones':prob}, index=n)
x
# Out:
#          Simulaciones
# 10           1.100052
# 1000         1.125488
# 10000        1.121182
# 100000       1.120191
# 1000000      1.120901

# %% [markdown]
# Con estas simulaciones y el histograma que se muestra a continuación podemos confirmar nuestra hipótesis, donde dijimos que el sexo más recurrente era el de hombre.

# %%
n = 1; p = 0.2889; N = 10**4

p_acum = P_acum_Binomial_o(n,p)
u = np.random.rand(N)

# Usando el método de la transformada inversa
d_binomial = Gen_distr_discreta(u,p_acum)
plot_histogram_discrete(d_binomial,'usando función creada')

# %% [markdown]
# Por último para este nodo, con la función que teníamos creada anteriormente hacemos una similación del histograma con los datos y nuestra distribución discreta.
#
# Se puede apreciar como la mayoría son hombres.

# %% [markdown]
# ## <font color = "darkgreen"> Nodo 3: Víctimas en el accidente

# %% [markdown]
# En este apartado se verán el número de fallecidos en el percance, viendo la edad y el sexo y de estos nos centraremos en la edad de las personas que fallecieron para así analizar la ocurrencia.

# %%
edad_fall = datos.iloc[:, 8:9]
sexo_fall = datos.iloc[:, 6:7]
muertes = datos.iloc[:, 2:3]

# %%
hist_victimas = muertes.plot.hist(grid=True, bins=10, rwidth=0.9, color='lightblue')

# %% [markdown]
# En este histograma vemos cuantas son las personas que normalmente fallece, es decir, si hay un choque normalmente solo muere una persona, pocas veces 3 y 4.

# %%
hist_sexo_victimas = sexo_fall.plot.hist(grid=True, bins=2, rwidth=0.9, color='lightpink')

# %% [markdown]
# Este histograma nos muestra el sexo de las víctimas, como podemos observar los hombres tienen un índice más alto de muerte. Con esto,  podemos decir que rechazamos otro punto que establecimos en nuestras hipótesis, el cual decía que el sexo más afectado sería el femenino.

# %%
hist_edad_victimas = edad_fall.plot.hist(grid=True, bins=10, rwidth=0.9, color='lightgreen')

# %% [markdown]
# Con este histograma podemos observar que las personas fallecidas estaban en el rango de 20 a 38 años aprox.
#
# Aquí podemos decir que otro punto de nuestras hipótesis se cumple, ya que habíamos propuesto que la edad más frecuentada en los accidentes sería de 30 años, y si observamos el histograma, se puede apreciar que el número más frecuente esta en el 30 y 32 años.

# %%
total_muertes = datos.iloc[:, 2:3].sum()
total_muertes
# Out:
# Number_of_Casualties    324
# dtype: int64

# %% [markdown]
# Aquí podemos ver el total de personas que murieron que fueron 324, pero nos centraremos en analizar a que edad fue que hubo más fallecidos.  Veremos la edad y el sexo.

# %%
best_fit_distribution(edad_fall)
# Out:
# ('norm', (0.0, 1.0))

# %%
para3 = st.norm.fit(datos['Age_of_Casualty'])

# %% [markdown]
# ### **Prueba quantil-quantil**

# %%
# Histograma de las variables creadas
divisiones = 100 # Cantidad de barras en el histograma
plt.hist(datos['Age_of_Casualty'], divisiones, density=True, label='Edad del fallecido')
x = np.arange(0,90,.01)
y = st.norm.pdf(x, loc=para3[0], scale=para3[1])
plt.plot(x, y, 'k--')
plt.ylabel('Probability')
plt.grid()
plt.show()

# Gráfica de Q-Q entre las muestras creadas y una curva normal
st.probplot(datos['Age_of_Casualty'], (para3[0],para3[1]), dist="norm", plot=plt)
plt.grid()
plt.title('Distribución normal')
plt.xlabel('Normal theorical quantiles')
plt.ylabel('Data theorical quantiles')
plt.show()

# %% [markdown]
# Podemos observar como es que los puntos se ajustan a la línea recta, teniendo unos cuantos datos que no hacen exactamente pero no están tan dispersos.
#
# Para terminar de comprobar si ciertamente se distribuyen normal, hacemos la prueba de la chi cuadrada.

# %%
f, axes = plt.subplots(figsize=(10, 6))
# Plot a simple histogram with binsize determined automatically
sns.distplot(edad_fall, color="green", fit=st.norm, norm_hist=True)

# %% [markdown]
# En el histograma podemos observar la línea de color verde, la cual es la que más se ajusta y tiene su máxima altitud en la edad de 30 años aprox.

# %%
mu = np.mean(edad_fall)
sigma = np.std(edad_fall)
print("La media es  = ", mu)
print("La desviación estándar es = ", sigma)
# Out:
# La media es  =  Age_of_Casualty    37.330798
# dtype: float64
# La desviación estándar es =  Age_of_Casualty    16.897164
# dtype: float64

# %% [markdown]
# ### Se desea resolver la siguiente prueba de hipótesis
# > $H_0$: la distribución es normal con ´media= $\mu$´ y ´desviación estándar = $\sigma$´
#
# > $H_a$: los datos no se distribuyen normales

# %%
np.random.seed(555)
mu_real = mu; sigma_real = sigma
N = 100 # Cantidad de muestras
n1 = datos["Age_of_Casualty"]
# datos aqui en n1 para el proyecto
J = 90  # Cantidad de particiones del histograma
[freq,x,p] = plt.hist(n1,J,density=True)
plt.show()
# Se obvia el último valor de x para obtener exactamente J muestras de x
x = x[:-1] 
# Media y desviación estándar muestral
mu = np.mean(x)
sigma = np.std(x)
print('media mu =%f, desviación estándar muestral =%f'%(mu, sigma))
st.norm.fit(x)
# Out:
# media mu =45.027778, desviación estándar muestral =24.535872
# (45.02777777777778, 24.535871740323657)

# %%
pi = st.norm.pdf(x,loc=mu,scale=sigma)
# Cálculo de la esperanza usando la expresión teórica
Ei = x*pi
# Cálculo teórico de la chi cuadrada
x2 = np.sum(list(map(lambda Ei,obs_i:(obs_i-Ei)**2/Ei,Ei,freq)))
print('Valor de chi cuadrado teorico  = ',x2)

# Cálculo usando la librería estadística de la chi cuadrada
X2 = st.chisquare(freq,Ei)
print('Valor de chi cuadrado librería = ',X2)

# Cálculo de Grados de libertad del estadístico
p = 2 # Parámetros estimados con los datos
m = J-p-1 # grados de libertad

Chi_est = st.chi2.ppf(q = 0.95, df=m)
print('Estadístico de chi_cuadrado = ', Chi_est)
print('Media muestral = ', mu, '\nDesviación estándar muestral = ', sigma)
# Out:
# Valor de chi cuadrado teorico  =  41.674561899343004
# Valor de chi cuadrado librería =  Power_divergenceResult(statistic=41.674561899343004, pvalue=0.9999955451889544)
# Estadístico de chi_cuadrado =  109.77330935028795
# Media muestral =  45.02777777777778
# Desviación estándar muestral =  24.535871740323657

# %% [markdown]
# Al observar la misma chi cuadrada y un pvalue de 0.9999955 que se dice es un valor grande, por lo tanto, $H_0$ se acepta y concluimos que es normal la distribución.

# %%
x3 = datos["Age_of_Casualty"]
grid = GridSearchCV(KernelDensity(),
                    {'bandwidth': np.linspace(0.1, 1.0, 30)},
                    cv=20) # 20-fold cross-validation
grid.fit(x3[:, None])
print(grid.best_params_)
x3_grid = np.linspace(0.1, x3.max(), 1000)
kde = grid.best_estimator_
pdf = np.exp(kde.score_samples(x3_grid[:,None]))

fig, ax = plt.subplots(figsize=(15,7))
ax.plot(x3_grid, pdf, linewidth=3, alpha=0.5, label='bw=%.2f' % kde.bandwidth)
ax.hist(x3, 100, fc='gray', histtype='stepfilled', alpha=0.3, density=True)
ax.legend(loc='upper left')
ax.set_xlim(18, 90);
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# {'bandwidth': 1.0}

# %% [markdown]
# La gráfica anterior nos muestra, en color gris las edades de los fallecidos, mientras que las curvas azules muestran el kernel del tipo de datos que tenemos, con el ajuste.

# %%
x3_grid = np.linspace(0.1, x3.max(), 1000)
funcion3 = kde_sklearn1(x3, x3_grid)
funcion3
# Out:
# <function __main__.kde_sklearn1.<locals>.<lambda>(x)>

# %%
x = np.arange(0, x3.max() + 1)
f = funcion3
max_f = max(funcion3(x))
t = lambda x: max_f * np.ones(len(x)) 

print('El maximo de f es:', max_f)

#Graficas de las funciones
plt.subplots(figsize=(8,6))
plt.title("Edad de muerte", size= 20)
plt.xlabel("Edad de muerte")
plt.ylabel("Probabilidad")
plt.plot(f(x), label='f(x)', linewidth=2, color = 'purple')
#plt.plot(t(x), label= 't(x)', linewidth=2, color = 'orange')

N = 500
R2 = np.random.uniform(0,1.5,N)
R1 = np.round(np.random.uniform(0, 100, N), 0)

aceptar3 = Acep_rechazo(R2, R1, f, t)
# Out:
# El maximo de f es: 0.10618272344056555

# %%
# Método montecarlo estándar 
monte_estandar = aceptar3
plt.hist(monte_estandar,40,density=True, color="purple")
plt.title('Montecarlo estándar')
plt.show()

# %%
n = [10, 1000, 10000, 100000, 1000000]
simu_edad_fall = list(map(lambda n:st.norm.rvs(loc=para3[0], scale=para3[1], size=n), n))
prob = list(map(lambda x: np.mean(x), simu_edad_fall)) 
x = pd.DataFrame(data={'Simulaciones':prob}, index=n)
x
# Out:
#          Simulaciones
# 10          42.018488
# 1000        37.310685
# 10000       37.389880
# 100000      37.336490
# 1000000     37.316462

# %% [markdown]
# Hicimos simulaciones de nuestra distribución y los parámetros que tenemos y nos da que la edad más recurrente se encuentra entre los 37 y 39 años.

# %%
N = 1000
# Método montecarlo estándar 
monte_estandar = st.norm.ppf(np.random.rand(N), loc=para3[0], scale=para3[1])
plt.hist(monte_estandar,30,density=True, color="green")
plt.title('Montecarlo estándar')
plt.show()
monte_estandar.mean()
# Out:
# 37.65367770711523

# %% [markdown]
# Por esto concluimos que la hipótesis que pusimos al inicio de que la edad con mayor decesos era de 30, ahora rechazamos esta hipótesis, ya que con las simulaciones y el histograma vemos que la edad más frecuente es de 37.

# %% [markdown]
# ## <font color = "darkgreen"> Nodo 4: Autos involucrados

# %% [markdown]
# Por último en este apartado se verán los vehículos que con más recurrencia chocan. Para esto estarán nombrados por números, como se dice enseguida:
# - Automóvil	-----> 1
# - Motocicleta	-----> 2
# - Bicicleta	-----> 3
# - Camión urbano de pasajeros	-----> 4
# - Camioneta de pasajeros	-----> 5
# - Camioneta de carga	-----> 6
# - Camión de carga	-----> 7
# - Microbús	-----> 8
# - Ómnibus	-----> 9
# - Tren eléctrico o trolebús	-----> 10

# %%
vehiculos = datos.iloc[:, 1:2]

# %%
hist_vehiculos = vehiculos.plot.hist(grid=True, bins=10, rwidth=.9, color='purple')

# %% [markdown]
# Al observar este histograma, aceptamos otro punto planteado en nuestras hipótesis, el cual dice que el vehículo más involucrado es el automóvil, sólo falta agregar que de igual manera, el otro vehículo involucrado es la motocicleta.

# %%
mu = np.mean(vehiculos)
sigma = np.std(vehiculos)
print("La media es  = ", mu)
print("La desviación estándar es = ", sigma)
# Out:
# La media es  =  Number_of_Vehicles    2.490494
# dtype: float64
# La desviación estándar es =  Number_of_Vehicles    1.890265
# dtype: float64

# %%
best_fit_distribution(vehiculos)
# Out:
# ('norm', (0.0, 1.0))

# %% [markdown]
# Para nosotras es claro que la distribución no es normal entonces la trabajaremos a continuación como una exponencial.

# %%
para4 = st.expon.fit(np.asarray(datos['Number_of_Vehicles']))
para4[1]
# Out:
# 1.4904942965779466

# %%
# Histograma de las variables creadas
divisiones = 50  # Cantidad de barras en el histograma
plt.hist(datos['Number_of_Vehicles'], divisiones, density=True, label='Número de vehículos')
x = np.arange(0,10,.1)
y = st.expon.pdf(x, loc = para4[0], scale=para4[1])
plt.plot(x, y, 'k--', label='Número de vehículos')
plt.ylabel('Probability')
plt.grid()
plt.show()

# Gráfica de Q-Q entre las muestras creadas 
grap1 = st.probplot(datos['Number_of_Vehicles'], (para4[0],para4[1]), dist="expon", plot=plt)
plt.grid()
plt.show()

# %% [markdown]
# Efectivamente, podemos observar que el vehículo más involucrado es el automóvil, ya que en el 1 (automóvil) está el máximo de la distribución, seguido por la motocicleta.
#
# Y como podemos observar en la segunda gráfica, los puntos no se ajustan a la línea recta, esto es porque nuestros datos son discretos.

# %%
f, axes = plt.subplots(figsize=(10, 6))
# Plot a simple histogram with binsize determined automatically
sns.distplot(vehiculos, color="purple", fit=st.expon)

# %% [markdown]
# En este histograma, podemos observar la línea morada, la cual es la que mejor se ajusta y en esa misma podemos observar que su punto máximo está en el número 1, el cual hace referrencia a automóvil.

# %% [markdown]
# ### Hacemos la conversión a kernel para poder hacer que se ajuste muy bien y después de esto obtenemos la función para poder hacer aceptación y rechazo.

# %%
kernel(datos["Number_of_Vehicles"], "Vehículos")
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# (array([4.18226529e-18, 1.01536639e-17, 2.44100652e-17, 5.81098898e-17,
#         1.36982825e-16, 3.19754848e-16, 7.39099846e-16, 1.69170269e-15,
#         3.83424554e-15, 8.60539395e-15, 1.91247843e-14, 4.20879032e-14,
#         9.17176646e-14, 1.97917246e-13, 4.22911257e-13, 8.94849098e-13,
#         1.87493112e-12, 3.89005539e-12, 7.99210547e-12, 1.62592902e-11,
#         3.27549478e-11, 6.53412133e-11, 1.29072116e-10, 2.52471652e-10,
#         4.89021291e-10, 9.37946067e-10, 1.78140604e-09, 3.35029405e-09,
#         6.23932901e-09, 1.15060909e-08, 2.10112878e-08, 3.79937791e-08,
#         6.80310651e-08, 1.20624910e-07, 2.11788164e-07, 3.68214871e-07,
# ...

# %%
x4 = datos["Number_of_Vehicles"]
grid = GridSearchCV(KernelDensity(),
                    {'bandwidth': np.linspace(0.1, 1.0, 30)},
                    cv=20) # 20-fold cross-validation
grid.fit(x4[:, None])
print(grid.best_params_)
x4_grid = np.linspace(0.1, x4.max(), 1000)
# Out:
# {'bandwidth': 0.1}
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)

# %%
x4_grid = np.linspace(0.1, x4.max(), 1000)
funcion4 = kde_sklearn1(x4, pdf)
funcion4
# Out:
# <function __main__.kde_sklearn1.<locals>.<lambda>(x)>

# %%
x = np.arange(0, x4.max() + 1)
f = funcion4
max_f = max(funcion4(x))
t = lambda x: max_f * np.ones(len(x)) 

print('El maximo de f es:', max_f)

#Graficas de las funciones
plt.subplots(figsize=(8,6))
plt.title("Vehículos", size= 20)
plt.xlabel("Vehículos")
plt.ylabel("Probabilidad")
plt.plot(f(x), label='f(x)', linewidth=2, color = 'purple')
#plt.plot(t(x), label= 't(x)', linewidth=2, color = 'orange')

N = 500
R2 = np.random.uniform(0,1,N)
R1 = np.round(np.random.uniform(0, 10, N), 0)

aceptar4 = Acep_rechazo(R2, R1, f, t)
# Out:
# El maximo de f es: 0.8115383304099486

# %%
# Método montecarlo estándar 
monte_estandar = aceptar4
plt.hist(monte_estandar,10, rwidth=0.9,density=True, color="orange")
plt.title('Montecarlo estándar')
plt.show()

# %%
n = [10,1000,10000,100000,1000000]
simu_vehiculos = list(map(lambda n:st.expon.rvs(loc=para4[0], scale=para4[1], size=n), n))
prob = list(map(lambda x: np.mean(x), simu_vehiculos)) 
x = pd.DataFrame(data={'Simulaciones':prob}, index=n)
x
# Out:
#          Simulaciones
# 10           2.476193
# 1000         2.512677
# 10000        2.514165
# 100000       2.488567
# 1000000      2.488799

# %%
N = 1000
# Método montecarlo estándar 
monte_estandar = st.expon.ppf(np.random.rand(N), loc=para4[0], scale=para4[1])
plt.hist(monte_estandar,10,density=True, color="pink")
plt.title('Montecarlo estándar')
plt.show()
monte_estandar.mean()
# Out:
# 2.396877299835568

# %%
theta = 4 # Media
N = 10**6 # Número de muestras
# creamos muestras exponenciales con la función creada
x2 = D_exponential(theta,N)
# Graficamos el historial para x
plt.hist(x2,100,density=True)
plt.xlabel('Valores aleatorios')
plt.ylabel('Probabilidad')
plt.title('Histograma')
print(np.mean(x2))
plt.show()
# Out:
# 3.9957176605298357
